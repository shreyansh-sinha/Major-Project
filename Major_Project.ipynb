# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyansh-sinha/Archade-Game-using-javascript/blob/master/Major_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ipaddress
# Importing the dataset
dataset = pd.read_csv('network_data_train.csv')
# print(dataset)
test_dataset = pd.read_csv('network_data_test.csv')
keep_col = ['frame.number','frame.time_relative','frame.len','ip.proto', 'tcp.seq', 'tcp.stream', 'tcp.options.timestamp.tsval', 'tcp.flags.syn', 'tcp.flags.ack', 'tcp.flags.fin', 'ip.src', 'ip.dst', 'eth.src', 'eth.dst', 'tcp.srcport', 'label']
new_f = dataset[keep_col]
# new_test_f = test_dataset[keep_col]
# new_test_f.to_csv("testnewFile.csv", index=False)
new_f.to_csv("newFile.csv", index=False)
 
dataset = pd.read_csv('newFile.csv')
# print(dataset)
# test_dataset = pd.read_csv('testnewFile.csv')
new_dataset = dataset
# new_test_dataset = test_dataset
 
new_dataset = new_dataset.fillna(0)
# new_test_dataset = new_test_dataset.fillna(0)
 
# new_dataset.astype(str)
# new_test_dataset.astype(str)
 
new_dataset = new_dataset.replace('normal', 'True')




# new_test_dataset = new_test_dataset.replace('normal', 1)
 
X = new_dataset.iloc[:, [1,2,3,4,5,6,7,8,9,14]].values
y = new_dataset.iloc[:, 15].values
print(y[146640])
y = [1 if x == 'True' else 0 for x in y]
new_dataset = new_dataset.replace('False', 0)

print(new_dataset)
print(y[146640])

c = 0
for data in y:
  if data == 1:
    c = c+1

print(y[146640])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# # Fitting classifier to the Training set
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion="entropy", max_depth=10)
print(classifier)
classifier.fit(X_train,y_train)
 
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print(cm)

def accuracy(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum / sum_of_all_elements

accurate = accuracy(cm)


print(accurate)
print(f1_score(y_test, y_pred, average="macro"))
print(precision_score(y_test, y_pred, average="macro"))
print(recall_score(y_test, y_pred, average="macro"))
# Out:
# 0
#         frame.number  frame.time_relative  ...  tcp.srcport  label
# 0                  1             0.000000  ...        554.0   True
# 1                  2             0.000036  ...      38405.0   True
# 2                  3             0.000118  ...        554.0   True
# 3                  4             0.000742  ...        554.0   True
# 4                  5             0.002389  ...        554.0   True
# ...              ...                  ...  ...          ...    ...
# 146636        146637            68.003308  ...      49231.0   True
# 146637        146638            68.003440  ...        554.0   True
# 146638        146639            68.003557  ...        554.0   True
# 146639        146640            68.003558  ...      49231.0   True
# 146640        146641            68.004207  ...          0.0      0
#
# [146641 rows x 16 columns]
# 0
# 0
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
# ...

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ipaddress
# Importing the dataset
dataset = pd.read_csv('sensor_train.csv')
print(dataset)
keep_col = ['frame.number','frame.time_relative','frame.len','ip.proto', 'tcp.seq', 'tcp.stream', 'tcp.options.timestamp.tsval', 'udp.length', 'udp.stream', 'ip.src', 'ip.dst', 'eth.src', 'eth.dst', 'udp.srcport', 'udp.dstport', 'label']
print(len(keep_col))
new_f = dataset[keep_col]
new_f.to_csv("sensorFile.csv", index=False)
 
dataset = pd.read_csv('sensorFile.csv')
# print(dataset)
# # test_dataset = pd.read_csv('testnewFile.csv')
new_dataset = dataset
# # new_test_dataset = test_dataset
 
new_dataset = new_dataset.fillna(0)
# # new_test_dataset = new_test_dataset.fillna(0)
 
# # new_dataset.astype(str)
# # new_test_dataset.astype(str)
 
new_dataset = new_dataset.replace('normal', 'True')




# # new_test_dataset = new_test_dataset.replace('normal', 1)
 
X = new_dataset.iloc[:, [0,1,2,3,4,5,6,7,8,13,14]].values
y = new_dataset.iloc[:, 15].values
# print(y[146640])
y = [1 if x == 'True' else 0 for x in y]
new_dataset = new_dataset.replace('False', 0)

print(new_dataset)
# print(y[146640])

# c = 0
# for data in y:
#   if data == 1:
#     c = c+1

# print(y[146640])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# # Fitting classifier to the Training set
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion="entropy", max_depth=10)
print(classifier)
classifier.fit(X_train,y_train)
 
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print(cm)

def accuracy(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum / sum_of_all_elements

accurate = accuracy(cm)


print(accurate)
print(f1_score(y_test, y_pred, average="macro"))
print(precision_score(y_test, y_pred, average="macro"))
print(recall_score(y_test, y_pred, average="macro"))
# Out:
#        frame.number  frame.time_relative  ...  udp.dstport   label
# 0                 1             0.000000  ...       5355.0  normal
# 1                 2             0.000512  ...       5355.0  normal
# 2                 3             0.024797  ...       5353.0  normal
# 3                 4             0.024799  ...       5353.0  normal
# 4                 5             0.044698  ...      10505.0  normal
# ...             ...                  ...  ...          ...     ...
# 21095         18288          4058.412520  ...       5353.0  normal
# 21096         18289          4058.423148  ...        137.0  normal
# 21097         18290          4058.471184  ...          NaN  normal
# 21098         18291          4058.585029  ...       5353.0  normal
# 21099         18292          4058.619091  ...          NaN  normal
#
# [21100 rows x 18 columns]
# 16
#        frame.number  frame.time_relative  ...  udp.dstport  label
# 0                 1             0.000000  ...       5355.0   True
# ...
